# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandergribenchenko/datacamp/blob/main/Introduction_to_APIs_in_python/NB_POC_API_Databricks_Examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

import pandas as pd

# %%
url_sample = "https://api.escuelajs.co/api/v1/products"

response = requests.request(method = "GET", url=url_sample)

json_response = json.loads(response.content)

json_response
# Out:
# [{'id': 3,
#   'title': 'Classic Heather Gray Hoodie',
#   'price': 69,
#   'description': 'Stay cozy and stylish with our Classic Heather Gray Hoodie. Crafted from soft, durable fabric, it features a kangaroo pocket, adjustable drawstring hood, and ribbed cuffs. Perfect for a casual day out or a relaxing evening in, this hoodie is a versatile addition to any wardrobe.',
#   'images': ['https://i.imgur.com/cHddUCu.jpeg',
#    'https://i.imgur.com/CFOjAgK.jpeg',
#    'https://i.imgur.com/wbIMMme.jpeg'],
#   'creationAt': '2024-09-30T16:59:20.000Z',
#   'updatedAt': '2024-09-30T16:59:20.000Z',
#   'category': {'id': 1,
#    'name': 'Clothes',
#    'image': 'https://i.imgur.com/QkIa5tT.jpeg',
#    'creationAt': '2024-09-30T16:59:20.000Z',
#    'updatedAt': '2024-09-30T16:59:20.000Z'}},
#  {'id': 4,
#   'title': 'Classic Grey Hooded Sweatshirt',
#   'price': 90,
# ...

# %%
url = "https://api.escuelajs.co/api/v1/products/2"

# payload = {
#   "email": "xxx@mail.com",
#   "name": "Gato Perro",
# }

# headers = {
#   'Content-Type': 'application/json',
#   'Authorization': 'Bearer ' + token
# }

response = requests.request('delete', url)

json_response_content = json.loads(response.content)

json_response_content
# Out:
# True

# %%
https://api.escuelajs.co/api/v1/users/1

# %%
url_sample = "https://api.escuelajs.co/api/v1/users/1"

response = requests.request(method = "GET", url=url_sample)

json_response = json.loads(response.content)

json_response
# Out:
# {'id': 1,
#  'email': 'john@mail.com',
#  'password': 'changeme',
#  'name': 'Jhon',
#  'role': 'customer',
#  'avatar': 'https://i.imgur.com/LDOO4Qs.jpg',
#  'creationAt': '2024-09-30T16:59:20.000Z',
#  'updatedAt': '2024-09-30T16:59:20.000Z'}

# %%
url = "https://api.escuelajs.co/api/v1/users"

payload = {
  "email": "alexander@gmail.com",
  "name": "Alexander",
  "role": "admin",
  "password": "4321",
  "avatar": "https://xxx.photos/800"
}

# headers = {
#   'Content-Type': 'application/json',
#   'Authorization': 'Bearer ' + token
# }

response = requests.request('post', url, data=payload)

# response = requests.request('post', url, data=json.dumps(payload))

json_response_content = json.loads(response.content)

json_response_content
# Out:
# {'email': 'alexander@gmail.com',
#  'password': '4321',
#  'name': 'Alexander',
#  'role': 'admin',
#  'avatar': 'https://xxx.photos/800',
#  'id': 18,
#  'creationAt': '2024-09-30T20:51:07.000Z',
#  'updatedAt': '2024-09-30T20:51:07.000Z'}

# %%
url_sample = "https://api.escuelajs.co/api/v1/users/17"

response = requests.request(method = "GET", url=url_sample)

json_response = json.loads(response.content)

json_response
# Out:
# {'id': 17,
#  'email': 'xxx@mail.com',
#  'password': '4321',
#  'name': 'Gato Perro',
#  'role': 'admin',
#  'avatar': 'https://xxx.photos/800',
#  'creationAt': '2024-09-30T20:46:49.000Z',
#  'updatedAt': '2024-09-30T20:48:02.000Z'}

# %%
url = "https://api.escuelajs.co/api/v1/users/17"

payload = {
  "email": "xxx@mail.com",
  "name": "Gato Perro",
}

# headers = {
#   'Content-Type': 'application/json',
#   'Authorization': 'Bearer ' + token
# }

response = requests.request('put', url, data=payload)

json_response_content = json.loads(response.content)

json_response_content
# Out:
# {'id': 17,
#  'email': 'xxx@mail.com',
#  'password': '4321',
#  'name': 'Gato Perro',
#  'role': 'admin',
#  'avatar': 'https://xxx.photos/800',
#  'creationAt': '2024-09-30T20:46:49.000Z',
#  'updatedAt': '2024-09-30T20:48:02.000Z'}

# %%
url = "https://api.escuelajs.co/api/v1/users/17"

# payload = {
#   "email": "xxx@mail.com",
#   "name": "Gato Perro",
# }

# headers = {
#   'Content-Type': 'application/json',
#   'Authorization': 'Bearer ' + token
# }

response = requests.request('delete', url)

json_response_content = json.loads(response.content)

json_response_content
# Out:
# True

# %%
url_sample = "https://api.escuelajs.co/api/v1/users"

response = requests.request(method = "GET", url=url_sample)

json_response = json.loads(response.content)

json_response
# Out:
# [{'id': 1,
#   'email': 'john@mail.com',
#   'password': 'changeme',
#   'name': 'Jhon',
#   'role': 'customer',
#   'avatar': 'https://i.imgur.com/LDOO4Qs.jpg',
#   'creationAt': '2024-09-30T16:59:20.000Z',
#   'updatedAt': '2024-09-30T16:59:20.000Z'},
#  {'id': 2,
#   'email': 'maria@mail.com',
#   'password': '12345',
#   'name': 'Maria',
#   'role': 'customer',
#   'avatar': 'https://i.imgur.com/DTfowdu.jpg',
#   'creationAt': '2024-09-30T16:59:20.000Z',
#   'updatedAt': '2024-09-30T16:59:20.000Z'},
#  {'id': 3,
#   'email': 'admin@mail.com',
#   'password': 'admin123',
#   'name': 'Admin',
#   'role': 'admin',
#   'avatar': 'https://i.imgur.com/yhW6Yw1.jpg',
#   'creationAt': '2024-09-30T16:59:20.000Z',
#   'updatedAt': '2024-09-30T16:59:20.000Z'},
#  {'id': 4,
#   'email': 'anujdahiya@admin.com',
#   'password': 'Anuj12',
#   'name': 'Anuj Dahiya',
#   'role': 'customer',
#   'avatar': 'https://i.imgur.com/LDOO4Qs.jpg',
#   'creationAt': '2024-09-30T17:20:16.000Z',
# ...

# %%
url_sample = "https://api.escuelajs.co/api/v1/users/11"

response = requests.request(method = "GET", url=url_sample)

json_response = json.loads(response.content)

json_response
# Out:
# {'id': 11,
#  'email': 'igor@email.com',
#  'password': 'teste1',
#  'name': 'Igor',
#  'role': 'customer',
#  'avatar': 'https://static.wikia.nocookie.net/liberproeliis/images/f/f4/Rick_Sanchez_C-137_dimension_preview.png/revision/latest?cb=20231022133205&path-prefix=pt-br',
#  'creationAt': '2024-09-30T20:02:40.000Z',
#  'updatedAt': '2024-09-30T20:02:40.000Z'}

# %%
response = requests.get('https://data.texas.gov/resource/ubdr-4uff.json')

# %%
response = requests.get('https://api.datacamp.com/users/12')
json_response_content = json.loads(response.content)
json_response_content
response.status_code
# Out:
# 404

# %%
# Defining the URL
url= 'https://data.texas.gov/resource/ubdr-4uff.json'

# Making the request
r = requests.get(url)
print("Status code:", r.status_code)

# Obtaining the JSON and converting it to a DataFrame
rjson = r.json()
df = pd.DataFrame.from_dict(rjson)
df
# Out:
# Status code: 200
#     complaint_number                                    respondent_name  \
# 0                  1                METROPOLITAN LIFE INSURANCE COMPANY
# 1                  2                       AETNA LIFE INSURANCE COMPANY
# 2                  3  BLUE CROSS AND BLUE SHIELD OF TEXAS, A DIVISIO...
# 3                  4  BLUE CROSS AND BLUE SHIELD OF TEXAS, A DIVISIO...
# 4                  5            CHARTER OAK FIRE INSURANCE COMPANY, THE
# ..               ...                                                ...
# 995              946  DAIRYLAND COUNTY MUTUAL INSURANCE COMPANY OF T...
# 996              947             ING LIFE INSURANCE AND ANNUITY COMPANY
# 997              948                   DIRECT GENERAL INSURANCE COMPANY
# 998              949                PHYSICIANS MUTUAL INSURANCE COMPANY
# 999              949                                    Wallace, Andrew
#
#            complainant_role                             reason  \
# ...

# %%
url = 'https://data.texas.gov/resource/ubdr-4uff.json?reason=Denial Of Claim'
r = requests.get(url)
rjson = r.json()
filtered_data = pd.DataFrame.from_dict(rjson)
filtered_data
# Out:
#     complaint_number                                    respondent_name  \
# 0                  3  BLUE CROSS AND BLUE SHIELD OF TEXAS, A DIVISIO...
# 1                  4  BLUE CROSS AND BLUE SHIELD OF TEXAS, A DIVISIO...
# 2                  8  BLUE CROSS AND BLUE SHIELD OF TEXAS, A DIVISIO...
# 3                 12  HEALTHSPRING LIFE & HEALTH INSURANCE COMPANY, ...
# 4                 15              ACCEPTANCE CASUALTY INSURANCE COMPANY
# ..               ...                                                ...
# 995             7604  BLUE CROSS AND BLUE SHIELD OF TEXAS, A DIVISIO...
# 996             7611         TEXAS FARM BUREAU MUTUAL INSURANCE COMPANY
# 997             7612                             ACCC INSURANCE COMPANY
# 998             7615                         NAUTILUS INSURANCE COMPANY
# 999             7632       ALLSTATE FIRE AND CASUALTY INSURANCE COMPANY
#
#     complainant_role           reason complaint_confirmed_code  \
# ...

# %%
url = 'https://data.texas.gov/resource/ubdr-4uff.json?coverage_type=Automobile'
r = requests.get(url)
rjson = r.json()
filtered_data = pd.DataFrame.from_dict(rjson)
filtered_data
# Out:
#     complaint_number                                    respondent_name  \
# 0                  5            CHARTER OAK FIRE INSURANCE COMPANY, THE
# 1                  7                     USAA GENERAL INDEMNITY COMPANY
# 2                 10       ALLSTATE FIRE AND CASUALTY INSURANCE COMPANY
# 3                 13  OLD AMERICAN COUNTY MUTUAL FIRE INSURANCE COMPANY
# 4                 13                       ROMERO INSURANCE AGENCY, LLC
# ..               ...                                                ...
# 995             3493     STATE FARM MUTUAL AUTOMOBILE INSURANCE COMPANY
# 996             3494     STATE FARM MUTUAL AUTOMOBILE INSURANCE COMPANY
# 997             3496  OLD AMERICAN COUNTY MUTUAL FIRE INSURANCE COMPANY
# 998             3500                         DRIVER'S INSURANCE COMPANY
# 999             3502  OLD AMERICAN COUNTY MUTUAL FIRE INSURANCE COMPANY
#
#            complainant_role  \
# 0                   Insured
# 1               Third Party
# ...

# %%
token = 'dapi7efd2545b62ffdbdc1c243606f018a6c'

# %% [markdown]
# # 01. Post method

# %%
url = "https://6009686077055686.6.gcp.databricks.com/api/2.1/jobs/run-now"

payload = {
  "job_id": 545929794148080,
  "notebook_params": {
    "sections": "Job description|Job Benefits|Job Requirements|Schedule",
    "vendor": "indeed.com",
    "driver_type": "Professional CDL-B for reefer",
    "salary": "125,000 per year",
    "availability": "inmediatly",
    "location": "New York"
  }
}
headers = {
  'Content-Type': 'application/json',
  'Authorization': 'Bearer ' + token
}

response = requests.request('post', url, headers=headers, data=json.dumps(payload))

json_response_content = json.loads(response.content)

json_response_content
# Out:
# {'run_id': 544443803822435, 'number_in_job': 544443803822435}

# %%
response.headers.get('content-type')
# Out:
# 'application/json'

# %%
response.headers['content-type']
# Out:
# 'application/json'

# %%
response.headers['accept']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-7a9fa16f9e44> in <cell line: 1>()
# ----> 1 response.headers['accept']
#
# /usr/local/lib/python3.10/dist-packages/requests/structures.py in __getitem__(self, key)
#      50
#      51     def __getitem__(self, key):
# ---> 52         return self._store[key.lower()][1]
#      53
#      54     def __delitem__(self, key):
#
# KeyError: 'accept'

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'run_id': 1001059200822731, 'number_in_job': 1001059200822731}

# %%
requests.codes.ok
# Out:
# 200

# %%
requests.codes.not_found
# Out:
# 404

# %% [markdown]
# # 02. Get method

# %%
url = "https://6009686077055686.6.gcp.databricks.com/api/2.1/jobs/get"

headers = {
  'Content-Type': 'text/plain',
  'Authorization': 'Bearer ' + token
}

payload =  {
  "job_id": 545929794148080
}


response = requests.request(method = "GET", url, headers=headers, data= json.dumps(payload))

json_response = json.loads(response.content)

json_response
# Out:
#   File "<ipython-input-3-289c3b2257c6>", line 13
#     response = requests.request(method = "GET", url, headers=headers, data= json.dumps(payload))
#                                                                                                ^
# SyntaxError: positional argument follows keyword argument

# %%
# Out:
# {'run_id': 8333465714918, 'number_in_job': 8333465714918}

# %%
url = "https://6009686077055686.6.gcp.databricks.com/api/2.1/jobs/get"

payload =  json.dumps({
  "job_id": 545929794148080
})
headers = {
  'Content-Type': 'text/plain',
  'Authorization': 'Bearer ' + token
}

response = requests.request("GET", url, headers=headers, data=payload)

json_response = json.loads(response.content)

json_response
# Out:
# {'job_id': 545929794148080,
#  'creator_user_name': 'alexander.ortega@level60consulting.com',
#  'run_as_user_name': 'alexander.ortega@level60consulting.com',
#  'run_as_owner': True,
#  'settings': {'name': 'Job_POC_GCP_Job_description',
#   'email_notifications': {'no_alert_for_skipped_runs': False},
#   'webhook_notifications': {},
#   'timeout_seconds': 0,
#   'max_concurrent_runs': 2,
#   'tasks': [{'task_key': 'LLM_Generator',
#     'run_if': 'ALL_SUCCESS',
#     'notebook_task': {'notebook_path': '/Repos/alexander.ortega@level60consulting.com/conversion-analytics/01_Databricks_Notebooks/NB_02_Conversion_POC',
#      'source': 'WORKSPACE'},
#     'existing_cluster_id': '1127-221004-oeneipmq',
#     'libraries': [{'pypi': {'package': 'openai==0.28.1'}}],
#     'timeout_seconds': 0,
#     'email_notifications': {},
#     'notification_settings': {'no_alert_for_skipped_runs': False,
#      'no_alert_for_canceled_runs': False,
#      'alert_on_last_attempt': False},
# ...

# %%
url = "https://6009686077055686.6.gcp.databricks.com/api/2.1/jobs/run-now"

payload = json.dumps({
  "job_id": 545929794148080,
  "notebook_params": {
    "sections": "Job description|Job Benefits|Job Requirements|Schedule",
    "vendor": "indeed.com",
    "driver_type": "Professional CDL-B for reefer",
    "salary": "125,000 per year",
    "availability": "inmediatly",
    "location": "New York"
  }
})
headers = {
  'Content-Type': 'application/json',
  'Authorization': 'Bearer ' + token
}

response = requests.request('post', url, headers=headers, data=payload)

print(response.text)
# Out:
# {"run_id":873049206433349,"number_in_job":873049206433349}

# %%
token = 'dapi7efd2545b62ffdbdc1c243606f018a6c'

# Cuerpo del JSON
data = {
    "job_id": 545929794148080,
    "notebook_params": {
        "sections": "Job description|Job Benefits|Job Requirements|Schedule",
        "vendor": "indeed.com",
        "driver_type": "Professional CDL-B for reefer",
        "salary": "125,000 per year",
        "availability": "inmediatly",
        "location": "New York"
    }
}

# Convertimos el cuerpo JSON a una cadena
json_data = json.dumps(data)

# Usamos ! para ejecutar el comando curl en shell
# !curl --location --request POST 'https://6009686077055686.6.gcp.databricks.com/api/2.1/jobs/run-now' \
--header 'Content-Type: application/json' \
--header 'Authorization: Bearer {token}' \
--data '{json_data}'
# Out:
# {"run_id":563855870623071,"number_in_job":563855870623071}
